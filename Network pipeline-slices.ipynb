# %%
from MAG_network import CitationNetwork
import os 
from matplotlib import pyplot as plt
import pandas as pd
import findspark
import MAGspark 

import sys

sys.path.insert(0,"/home/laal/MAG/CentralityFairness/Evaluations")

# from Evaluations.Evaluator import Evaluator


# set environment variables
os.environ["SPARK_LOCAL_DIRS"] = "/home/laal/MAG/TMP"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-1.8.0-openjdk-1.8.0.242.b08-0.el7_7.x86_64"
os.environ['SPARK_HOME'] = "/home/laal/MAG/spark-3.0.2-bin-hadoop2.7"

# %%
mag, spark = MAGspark.get_mag_with_cluster_connection(jobid=40825, memory_per_executor=14000,
                                                      data_folderpath="/home/laal/MAG/DATA/")
# Out:
# ['NAME STATE JOBID', 'simple-gpu PENDING 40830', 'simple-gpu PENDING 40831', 'muzero-gpu-job RUNNING 40603', 'generatedata RUNNING 40822', 'generatedata RUNNING 40829', 'ETL_wikidata_dump RUNNING 40537', 'sparkcluster RUNNING 40844', 'train-network2 RUNNING 40845', 'train-network-incv RUNNING 40638', 'ant_bullet RUNNING 40631', 'ant_bullet RUNNING 40629', 'ant_bullet RUNNING 40628', 'ant_bullet RUNNING 40627', 'jupyter RUNNING 40835', 'covid19tweets RUNNING 40852', 'covid19tweets RUNNING 40848', '']

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://desktop16.hpc.itu.dk:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.stop()

# %%
def build_wacn_graphs(fos_id, fos_name, root_data_folder, csv_filepath):
    
    network = CitationNetwork(mag, fos_id=fos_id, fos_name=fos_name, root_data_folder=root_data_folder)
    network.check_references_and_citations(overwrite=False)

    print("Extracting ordered references")
    
    # papers = network.mag.getDataframe('Papers')
    # paper_refs = network.mag.getDataframe(network.paper_references_name)
    
    if not os.path.exists(csv_filepath):
        return
    
    slice_df = pd.read_csv(csv_filepath)
        
    # loop over rows and create networks
    for record in slice_df.to_dict('records'):
        
        if os.path.exists("/home/laal/MAG/DATA/NETWORKS/SimpleWeight{}2020Slice{}Centrality.csv".
                         format(fos_name, record['slice_index'])):
            continue
        
        print("Extracting {} slice index {} / {}".format(fos_name, record['slice_index'], len(slice_df)))

        network_name = "SimpleWeight{}2020Slice{}".format(fos_name, record['slice_index'])
        
        network.load_author_author_network(network_name)
        graph, node_mapping, eweight = network.build_graph()
        df = network.compute_centralities(graph, node_mapping, eweight, "", pr_damping=0.85)
        df['sliceid'] = record['slice_index']
        
        if record['slice_index'] == 0:
            df.to_csv("/home/laal/MAG/DATA/NETWORKS/SimpleWeight{}2020SliceMasterCentrality.csv"
                      .format(fos_name), index=False, header=False, sep="\t")
        else:
            df.to_csv("/home/laal/MAG/DATA/NETWORKS/SimpleWeight{}2020SliceMasterCentrality.csv"
                      .format(fos_name), index=False, header=False, mode='a', sep="\t")        
            
    network.append_gender_and_macrank("SimpleWeight{}2020SliceMasterCentrality".format(fos_name))

# %%
build_wacn_graphs(162324750, 'Economics', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Economics2020.csv")
# Out:
# Paper references and citations available for Economics
# Extracting ordered references
# Gendered centrality measures saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020SliceMasterCentralityGendered.csv

# %%
build_wacn_graphs(15744967, 'Psychology', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Psychology2020.csv")
# Out:
# Paper references and citations available for Psychology
# Extracting ordered references
# INFO:py4j.java_gateway:Error while receiving.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1033, in send_command
#     response = connection.send_command(command)
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1211, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while receiving
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:35511)
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in _get_connection(self)
#     976         try:
# --> 977             connection = self.deque.pop()
#     978         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in start(self)
#    1114         try:
# -> 1115             self.socket.connect((self.address, self.port))
#    1116             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-5-2895a13d904b> in <module>
# ----> 1 build_wacn_graphs(15744967, 'Psychology', root_data_folder="/home/laal/MAG/DATA",
#       2                   csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Psychology2020.csv")
#
# <ipython-input-4-8c6e80afc39b> in build_wacn_graphs(fos_id, fos_name, root_data_folder, csv_filepath)
#      33                       .format(fos_name), index=False, header=False, mode='a', sep="\t")
#      34
# ---> 35     network.append_gender_and_macrank("SimpleWeight{}2020SliceMasterCentrality".format(fos_name))
#
# ~/MAG/CentralityFairness/MAG_network.py in append_gender_and_macrank(self, centrality_filename)
#     537         # run query and extract to Pandas dataframe
#     538         centrality = self.mag.query_sql(query)
# --> 539         centrality_df = centrality.toPandas()
#     540
#     541         csv_destination = self.root_folder + "/NETWORKS/{}".format(centrality_filename + 'Gendered.csv')
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/pandas/conversion.py in toPandas(self)
#     136
#     137         # Below is toPandas without Arrow optimization.
# --> 138         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     139         column_counter = Counter(self.columns)
#     140
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py in columns(self)
#    1030         ['age', 'name']
#    1031         """
# -> 1032         return [f.name for f in self.schema.fields]
#    1033
#    1034     @since(2.3)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py in schema(self)
#     254         if self._schema is None:
#     255             try:
# --> 256                 self._schema = _parse_datatype_json_string(self._jdf.schema().json())
#     257             except AttributeError as e:
#     258                 raise Exception(
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1029          if `binary` is `True`.
#    1030         """
# -> 1031         connection = self._get_connection()
#    1032         try:
#    1033             response = connection.send_command(command)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in _get_connection(self)
#     977             connection = self.deque.pop()
#     978         except IndexError:
# --> 979             connection = self._create_connection()
#     980         return connection
#     981
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in _create_connection(self)
#     983         connection = GatewayConnection(
#     984             self.gateway_parameters, self.gateway_property)
# --> 985         connection.start()
#     986         return connection
#     987
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in start(self)
#    1125                 "server ({0}:{1})".format(self.address, self.port)
#    1126             logger.exception(msg)
# -> 1127             raise Py4JNetworkError(msg, e)
#    1128
#    1129     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:35511)

# %%
build_wacn_graphs(33923547, 'Mathematics', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Mathematics2020.csv")
# Out:
# Paper references and citations available for Mathematics
# Extracting ordered references
# Extracting Mathematics slice index 0 / 33
# part-00000-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00001-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00002-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00003-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00004-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00005-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00006-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00007-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00008-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00009-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00010-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00011-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00012-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00013-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00014-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00015-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# part-00016-28d6831e-fb37-4d52-91c2-ec8c45eaec93-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice0Centrality.csv
# Extracting Mathematics slice index 1 / 33
# part-00000-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00001-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00002-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00003-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00004-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00005-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00006-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00007-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00008-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00009-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00010-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00011-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00012-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00013-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00014-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00015-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# part-00016-55830bb1-2cde-4297-802d-f0bd0692a82a-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice1Centrality.csv
# Extracting Mathematics slice index 2 / 33
# part-00000-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00001-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00002-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00003-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00004-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00005-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00006-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00007-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00008-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00009-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00010-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00011-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00012-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00013-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00014-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00015-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# part-00016-85943559-6417-47ac-893e-6d320a3a319b-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice2Centrality.csv
# Extracting Mathematics slice index 3 / 33
# part-00000-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00001-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00002-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00003-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00004-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00005-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00006-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00007-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00008-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00009-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00010-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00011-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00012-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00013-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00014-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00015-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# part-00016-9e8befff-6c15-405d-9ed6-9d3383e9dd79-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice3Centrality.csv
# Extracting Mathematics slice index 4 / 33
# part-00000-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00001-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00002-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00003-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00004-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00005-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00006-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00007-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00008-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00009-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00010-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00011-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00012-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00013-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00014-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00015-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# part-00016-3d0bdb40-0920-4ff6-9316-7223ffc61373-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice4Centrality.csv
# Extracting Mathematics slice index 5 / 33
# part-00000-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00001-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00002-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00003-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00004-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00005-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00006-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00007-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00008-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00009-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00010-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00011-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00012-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00013-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00014-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00015-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# part-00016-c474df2a-51ae-4752-90bd-cfb9dd25b7e8-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice5Centrality.csv
# Extracting Mathematics slice index 6 / 33
# part-00000-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00001-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00002-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00003-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00004-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00005-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00006-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00007-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00008-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00009-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00010-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00011-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00012-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00013-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00014-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00015-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# part-00016-77a4b73d-1e89-4072-8221-ad3702cc3dc1-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice6Centrality.csv
# Extracting Mathematics slice index 7 / 33
# part-00000-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00001-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00002-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00003-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00004-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00005-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00006-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00007-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00008-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00009-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00010-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00011-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00012-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00013-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00014-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00015-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# part-00016-0d8c5f8b-299c-46cd-8f97-ee6244eca066-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice7Centrality.csv
# Extracting Mathematics slice index 8 / 33
# part-00000-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00001-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00002-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00003-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00004-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00005-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00006-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00007-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00008-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00009-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00010-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00011-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00012-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00013-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00014-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00015-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# part-00016-cc1c71b1-d329-4d83-a28b-a2a42e8e29f6-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice8Centrality.csv
# Extracting Mathematics slice index 9 / 33
# part-00000-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00001-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00002-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00003-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00004-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00005-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00006-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00007-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00008-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00009-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00010-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00011-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00012-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00013-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00014-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00015-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# part-00016-53ab0d04-c945-42bb-9b82-8a2d008a390b-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice9Centrality.csv
# Extracting Mathematics slice index 10 / 33
# part-00000-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00001-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00002-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00003-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00004-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00005-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00006-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00007-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00008-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00009-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00010-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00011-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00012-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00013-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00014-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00015-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# part-00016-8bd4532c-ccdb-4055-b359-70c6b5673f2f-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice10Centrality.csv
# Extracting Mathematics slice index 11 / 33
# part-00000-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00001-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00002-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00003-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00004-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00005-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00006-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00007-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00008-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00009-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00010-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00011-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00012-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00013-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00014-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00015-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# part-00016-6177999d-942b-44f7-9f82-a4c9a8b95135-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice11Centrality.csv
# Extracting Mathematics slice index 12 / 33
# part-00000-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00001-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00002-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00003-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00004-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00005-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00006-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00007-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00008-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00009-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00010-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00011-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00012-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00013-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00014-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00015-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# part-00016-4e09fc0b-89ab-4c76-a8ce-094b211e68ab-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice12Centrality.csv
# Extracting Mathematics slice index 13 / 33
# part-00000-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00001-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00002-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00003-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00004-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00005-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00006-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00007-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00008-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00009-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00010-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00011-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00012-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00013-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00014-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00015-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# part-00016-8562c413-942b-4e4f-a56a-b548208c57d0-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice13Centrality.csv
# Extracting Mathematics slice index 14 / 33
# part-00000-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00001-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00002-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00003-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00004-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00005-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00006-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00007-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00008-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00009-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00010-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00011-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00012-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00013-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00014-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00015-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# part-00016-de2b34c0-4932-43db-9bf9-138f9d987bb8-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice14Centrality.csv
# Extracting Mathematics slice index 15 / 33
# part-00000-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00001-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00002-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00003-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00004-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00005-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00006-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00007-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00008-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00009-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00010-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00011-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00012-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00013-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00014-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00015-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# part-00016-f46738d4-f690-48c6-be88-03e18f4de49b-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice15Centrality.csv
# Extracting Mathematics slice index 16 / 33
# part-00000-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00001-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00002-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00003-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00004-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00005-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00006-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00007-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00008-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00009-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00010-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00011-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00012-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00013-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00014-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00015-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# part-00016-4457314c-4c0e-4541-a8ee-a4a998756e6b-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice16Centrality.csv
# Extracting Mathematics slice index 17 / 33
# part-00000-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00001-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00002-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00003-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00004-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00005-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00006-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00007-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00008-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00009-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00010-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00011-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00012-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00013-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00014-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00015-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# part-00016-4c18218b-4c02-4092-ad48-4502b36688d0-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice17Centrality.csv
# Extracting Mathematics slice index 18 / 33
# part-00000-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00001-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00002-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00003-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00004-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00005-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00006-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00007-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# part-00008-513a5e09-a941-40e8-aa1a-2b36212a1045-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice18Centrality.csv
# Extracting Mathematics slice index 19 / 33
# part-00000-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00001-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00002-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00003-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00004-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00005-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00006-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00007-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00008-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00009-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00010-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00011-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00012-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00013-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00014-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00015-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# part-00016-40cf24ee-54b8-419c-ba59-9484fa02f89e-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice19Centrality.csv
# Extracting Mathematics slice index 20 / 33
# part-00000-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00001-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00002-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00003-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00004-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00005-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00006-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00007-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00008-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00009-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00010-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00011-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00012-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00013-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00014-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00015-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# part-00016-8ebe5875-a020-4b7a-9c03-b8df4373eb5e-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice20Centrality.csv
# Extracting Mathematics slice index 21 / 33
# part-00000-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00001-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00002-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00003-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00004-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00005-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00006-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00007-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00008-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00009-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00010-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00011-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00012-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00013-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00014-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00015-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# part-00016-4f49d5fe-0bde-47a3-9f91-0e3d2e947233-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice21Centrality.csv
# Extracting Mathematics slice index 22 / 33
# part-00000-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00001-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00002-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00003-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00004-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00005-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00006-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00007-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00008-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00009-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00010-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00011-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00012-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00013-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00014-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00015-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# part-00016-d2ac71c5-70dc-43cb-8476-f9641600072e-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice22Centrality.csv
# Extracting Mathematics slice index 23 / 33
# part-00000-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00001-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00002-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00003-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00004-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00005-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00006-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00007-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00008-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00009-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00010-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00011-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00012-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00013-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00014-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00015-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# part-00016-fc4dab2a-f2af-4ea7-a22f-1251c7c8b601-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice23Centrality.csv
# Extracting Mathematics slice index 24 / 33
# part-00000-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00001-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00002-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00003-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00004-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00005-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00006-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00007-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00008-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00009-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00010-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00011-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00012-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00013-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00014-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00015-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# part-00016-a5c66c2b-b3c0-451f-8426-94087e0b69e3-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice24Centrality.csv
# Extracting Mathematics slice index 25 / 33
# part-00000-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00001-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00002-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00003-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00004-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00005-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00006-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00007-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00008-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00009-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00010-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00011-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00012-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00013-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00014-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00015-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# part-00016-ed83153e-b3de-47f0-a1b6-b4f082610a8d-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice25Centrality.csv
# Extracting Mathematics slice index 26 / 33
# part-00000-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00001-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00002-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00003-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00004-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00005-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00006-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00007-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00008-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00009-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00010-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00011-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00012-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00013-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00014-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00015-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# part-00016-fddb5b41-9cbd-40a4-bec4-77de3bac088f-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice26Centrality.csv
# Extracting Mathematics slice index 27 / 33
# part-00000-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00001-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00002-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00003-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00004-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00005-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00006-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00007-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00008-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00009-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00010-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00011-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00012-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00013-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00014-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00015-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# part-00016-ae0edf29-bc21-4585-8cbd-6ae0bee4840c-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice27Centrality.csv
# Extracting Mathematics slice index 28 / 33
# part-00000-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00001-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00002-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00003-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00004-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00005-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00006-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00007-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00008-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00009-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00010-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00011-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00012-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00013-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00014-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00015-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# part-00016-a2734da9-551e-419f-a818-f09b2b6ccf60-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice28Centrality.csv
# Extracting Mathematics slice index 29 / 33
# part-00000-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00001-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00002-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00003-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00004-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00005-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00006-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00007-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00008-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00009-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00010-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00011-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00012-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00013-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00014-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00015-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# part-00016-20b48232-2b66-4bcb-be44-4e4babcc0b06-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice29Centrality.csv
# Extracting Mathematics slice index 30 / 33
# part-00000-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00001-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00002-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00003-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00004-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00005-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00006-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00007-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00008-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00009-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00010-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00011-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00012-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00013-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00014-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00015-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# part-00016-7d2e6bf5-495a-4db8-ba73-9694420e07d6-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice30Centrality.csv
# Extracting Mathematics slice index 31 / 33
# part-00000-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00001-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00002-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00003-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00004-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00005-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00006-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00007-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00008-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00009-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00010-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00011-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00012-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00013-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00014-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00015-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# part-00016-42ed4322-e7b0-4341-afe3-6e090927373a-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice31Centrality.csv
# Extracting Mathematics slice index 32 / 33
# part-00000-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00001-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00002-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00003-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00004-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00005-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00006-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00007-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00008-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00009-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00010-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00011-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00012-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00013-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00014-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00015-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# part-00016-888ff3c5-2ede-417f-a417-6c099c88e578-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice32Centrality.csv
# INFO:py4j.java_gateway:Error while receiving.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1033, in send_command
#     response = connection.send_command(command)
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1211, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while receiving
# INFO:py4j.java_gateway:Error while receiving.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py", line 596, in collect
#     sock_info = self._jdf.collectToPython()
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1304, in __call__
#     return_value = get_return_value(
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/utils.py", line 128, in deco
#     return f(*a, **kw)
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o4579.collectToPython
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py", line 596, in collect
#     sock_info = self._jdf.collectToPython()
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1304, in __call__
#     return_value = get_return_value(
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/utils.py", line 128, in deco
#     return f(*a, **kw)
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o4579.collectToPython
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1033, in send_command
#     response = connection.send_command(command)
#   File "/home/laal/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py", line 1211, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py in collect(self)
#     595         with SCCallSiteSync(self._sc) as css:
# --> 596             sock_info = self._jdf.collectToPython()
#     597         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     127         try:
# --> 128             return f(*a, **kw)
#     129         except py4j.protocol.Py4JJavaError as e:
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     333         else:
# --> 334             raise Py4JError(
#     335                 "An error occurred while calling {0}{1}{2}".
#
# Py4JError: An error occurred while calling o4579.collectToPython
#
# During handling of the above exception, another exception occurred:
#
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-9-e65e6d97ee22> in <module>
# ----> 1 build_wacn_graphs(33923547, 'Mathematics', root_data_folder="/home/laal/MAG/DATA",
#       2                   csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Mathematics2020.csv")
#
# <ipython-input-8-0eb22bb1932a> in build_wacn_graphs(fos_id, fos_name, root_data_folder, csv_filepath)
#      33                       .format(fos_name), index=False, header=False, mode='a', sep="\t")
#      34
# ---> 35     network.append_gender_and_macrank("SimpleWeight{}2020SliceMasterCentrality".format(fos_name))
#
# ~/MAG/CentralityFairness/MAG_network.py in append_gender_and_macrank(self, centrality_filename)
#     537         # run query and extract to Pandas dataframe
#     538         centrality = self.mag.query_sql(query)
# --> 539         centrality_df = centrality.toPandas()
#     540
#     541         csv_destination = self.root_folder + "/NETWORKS/{}".format(centrality_filename + 'Gendered.csv')
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/pandas/conversion.py in toPandas(self)
#     136
#     137         # Below is toPandas without Arrow optimization.
# --> 138         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     139         column_counter = Counter(self.columns)
#     140
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/dataframe.py in collect(self)
#     594         """
#     595         with SCCallSiteSync(self._sc) as css:
# --> 596             sock_info = self._jdf.collectToPython()
#     597         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     598
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/traceback_utils.py in __exit__(self, type, value, tb)
#      76         SCCallSiteSync._spark_stack_depth -= 1
#      77         if SCCallSiteSync._spark_stack_depth == 0:
# ---> 78             self._context._jsc.setCallSite(None)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     126     def deco(*a, **kw):
#     127         try:
# --> 128             return f(*a, **kw)
#     129         except py4j.protocol.Py4JJavaError as e:
#     130             converted = convert_exception(e.java_exception)
#
# ~/.conda/envs/gtenv/lib/python3.9/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     332                     format(target_id, ".", name, value))
#     333         else:
# --> 334             raise Py4JError(
#     335                 "An error occurred while calling {0}{1}{2}".
#     336                 format(target_id, ".", name))
#
# Py4JError: An error occurred while calling o42.setCallSite

# %%
build_wacn_graphs(185592680, 'Chemistry', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Chemistry2020.csv")
# Out:
# Paper references and citations available for Chemistry
# Extracting ordered references
# Extracting Chemistry slice index 11 / 37
# part-00000-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00001-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00002-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00003-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00004-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00005-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00006-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00007-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00008-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00009-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00010-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00011-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00012-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00013-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00014-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00015-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00016-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00017-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00018-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00019-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00020-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00021-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00022-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00023-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00024-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00025-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00026-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00027-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00028-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00029-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00030-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00031-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00032-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00033-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00034-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00035-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00036-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00037-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00038-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00039-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00040-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00041-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00042-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00043-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00044-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00045-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00046-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00047-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00048-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00049-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00050-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00051-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00052-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00053-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00054-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00055-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00056-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00057-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00058-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00059-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00060-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00061-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00062-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00063-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00064-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00065-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00066-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00067-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00068-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00069-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00070-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00071-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00072-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00073-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00074-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00075-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00076-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00077-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00078-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00079-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00080-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00081-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00082-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00083-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00084-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00085-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00086-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00087-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00088-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00089-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00090-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00091-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00092-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00093-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00094-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00095-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00096-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00097-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00098-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# part-00099-6b0c10df-3e12-4755-804f-56335dd0a90a-c000.csv
# Initiating PageRank
# Initiating degree measures
# Finished centrality computations
# Centrality CSV saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice11Centrality.csv
# Extracting Chemistry slice index 12 / 37
# part-00000-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00001-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00002-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00003-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00004-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00005-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00006-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00007-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00008-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00009-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00010-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00011-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00012-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00013-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00014-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00015-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00016-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00017-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00018-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00019-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00020-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00021-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00022-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00023-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00024-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00025-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00026-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00027-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00028-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00029-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00030-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00031-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00032-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00033-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00034-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00035-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00036-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00037-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00038-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00039-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00040-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00041-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00042-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00043-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00044-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00045-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00046-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00047-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00048-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00049-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00050-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00051-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00052-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00053-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00054-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00055-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00056-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00057-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00058-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00059-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00060-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00061-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00062-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00063-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00064-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00065-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00066-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00067-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00068-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00069-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00070-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00071-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00072-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00073-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00074-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00075-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00076-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00077-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00078-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00079-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00080-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00081-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00082-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00083-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00084-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00085-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00086-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00087-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00088-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00089-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00090-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00091-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00092-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00093-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00094-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00095-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00096-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00097-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00098-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv
# part-00099-5fbeb0f7-9e40-43c0-9dbb-53e4ad586245-c000.csv

# %% [markdown]
# ### Rerun networks

# %%
id_names = [(185592680, 'Chemistry'), (15744967, 'Psychology'), (33923547, 'Mathematics'), (162324750, 'Economics')]

for fos_id, name in id_names:
    print("Starting network extraction for {}".format(name))
    
    network = CitationNetwork(mag, fos_id=fos_id, fos_name=name, root_data_folder="/home/laal/MAG/DATA")
    network.check_references_and_citations()
    network.save_author_network("SimpleWeight{}2020".format(name), mindate='1800-01-01', maxdate='2020-12-31')
    network.load_author_author_network("SimpleWeight{}2020".format(name))
    # network.nodelist_and_edge_count()    
    
    graph, node_mapping, eweight = network.build_graph()
    df = network.compute_centralities(graph, node_mapping, eweight, "", pr_damping=0.85)
    
    print("\n----------------------------\n")
# Out:
# Starting network extraction for Chemistry
# Paper references and citations available for Chemistry
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020.txt. Use overwrite to replace
# The network has 1361642334 edges
# The network has 15845298 nodes
# Gender distribution: -1    11910223
#  1     2580695
#  0     1354380
# Name: Gender, dtype: int64
#
# ----------------------------
#
# Starting network extraction for Psychology
# Paper references and citations available for Psychology
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020.txt. Use overwrite to replace
# The network has 419209380 edges
# The network has 4088513 nodes
# Gender distribution: -1    2464853
#  0     814668
#  1     808992
# Name: Gender, dtype: int64
#
# ----------------------------
#
# Starting network extraction for Mathematics
# Paper references and citations available for Mathematics
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020.txt. Use overwrite to replace
# The network has 94475729 edges
# The network has 3448598 nodes
# Gender distribution: -1    2479361
#  1     753573
#  0     215664
# Name: Gender, dtype: int64
#
# ----------------------------
#
# Starting network extraction for Economics
# Paper references and citations available for Economics
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020.txt. Use overwrite to replace
# The network has 43178968 edges
# The network has 1106221 nodes
# Gender distribution: -1    690485
#  1    304369
#  0    111367
# Name: Gender, dtype: int64
#
# ----------------------------

# %%
id_names = [(15744967, 'Psychology'), (33923547, 'Mathematics'), (162324750, 'Economics')]
id_names = [(185592680, 'Chemistry')]

for fos_id, name in id_names:
    print("Starting network extraction for {}".format(name))
    
    network = CitationNetwork(mag, fos_id=fos_id, fos_name=name, root_data_folder="/home/laal/MAG/DATA")
    network.check_references_and_citations()
    network.save_author_network("SimpleWeight{}2020".format(name), mindate='1800-01-01', maxdate='2020-12-31')
    network.load_author_author_network("SimpleWeight{}2020".format(name))
    
    # graph, node_mapping, eweight = network.build_graph()
    # network.compute_centralities(graph, node_mapping, eweight, "", pr_damping=0.85)
    network.append_gender_and_macrank()
    
    # network.nodelist_and_edge_count()    
    print("\n----------------------------\n")
# Out:
# Starting network extraction for Chemistry
# Paper references and citations available for Chemistry
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020.txt. Use overwrite to replace
# Gendered centrality measures saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020CentralityGendered.csv
#
# ----------------------------

# %%
id_names = [(15744967, 'Psychology'), (33923547, 'Mathematics'), (162324750, 'Economics'), (185592680, 'Chemistry')]

for fos_id, name in id_names:
    print("Starting network extraction for {}".format(name))
    
    network = CitationNetwork(mag, fos_id=fos_id, fos_name=name, root_data_folder="/home/laal/MAG/DATA")
    network.check_references_and_citations()
    network.save_author_network("SimpleWeight{}2020".format(name), mindate='1800-01-01', maxdate='2020-12-31')
    network.load_author_author_network("SimpleWeight{}2020".format(name))
    
    # graph, node_mapping, eweight = network.build_graph()
    # network.compute_centralities(graph, node_mapping, eweight, "", pr_damping=0.85)
    # network.append_gender_and_macrank()
    
    path = network.root_folder + "/NETWORKS/{}".format("SimpleWeight{}2020Centrality".format(name) + 'Gendered.csv')
    
    centrality = 'PageRank'
    
    metrics = ['rND', 'rKL', 'rRD', 'equal_ex']
    print('Evaluating', path, 'with sample size', sample, 'and centrality', centrality)
    
    evaluator = Evaluator(path, centrality, sample)
    evaluator.run_evaluations(metrics)
    
    # network.nodelist_and_edge_count()    
    print("\n----------------------------\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f819db0e0067> in <module>
#       3 sys.path.insert(0,"/home/laal/MAG/CentralityFairness/Evaluations")
#       4
# ----> 5 from Evaluations.Evaluator import Evaluator
#
# ~/MAG/CentralityFairness/Evaluations/Evaluator.py in <module>
#      10 sys.path.insert(0,parentdir)
#      11
# ---> 12 from lenskit.metrics.topnFair import *
#      13
#      14 class Evaluator:
#
# ~/MAG/CentralityFairness/Evaluations/lenskit/__init__.py in <module>
#       3 """
#       4
# ----> 5 from . import batch
#       6
#       7
#
# ~/MAG/CentralityFairness/Evaluations/lenskit/batch/__init__.py in <module>
#       3 """
#       4
# ----> 5 from ._predict import predict
#       6 from ._recommend import recommend
#       7 from ._multi import MultiEval
#
# ~/MAG/CentralityFairness/Evaluations/lenskit/batch/_predict.py in <module>
#       5 import pandas as pd
#       6
# ----> 7 from .. import util
#       8 from .. import crossfold
#       9
#
# ~/MAG/CentralityFairness/Evaluations/lenskit/util.py in <module>
#      12 from collections.abc import Iterable, Sequence
#      13
# ---> 14 from numba import jitclass, njit, int32, double
#      15 import numpy as np
#      16 import pandas as pd
#
# ModuleNotFoundError: No module named 'numba'

# %%
def build_wacn_slices(fos_id, fos_name, root_data_folder, csv_filepath):
    
    network = CitationNetwork(mag, fos_id=fos_id, fos_name=fos_name, root_data_folder=root_data_folder)
    network.check_references_and_citations(overwrite=False)

    print("Extracting ordered references")
    
    papers = network.mag.getDataframe('Papers')
    paper_refs = network.mag.getDataframe(network.paper_references_name)
    
    if not os.path.exists(csv_filepath):
        query = """
            SELECT pr.PaperId, pr.PaperReferenceId,
            p.Date as pubDate, 
            row_number() over (order by p.Date ASC) rownum
            FROM {} pr
            INNER JOIN Papers p ON pr.PaperId = p.PaperId
            WHERE p.Date is not null and p.Date <= '2020-12-31'
        """.format(network.paper_references_name)

        prefs_with_rownum = network.mag.query_sql(query)
        prefs_with_rownum.createOrReplaceTempView('PaperReferencesRownum')

        num_references = prefs_with_rownum.count()

        query = """
            SELECT 
            YEAR(pubDate), COUNT(*) as numReferences
            FROM PaperReferencesRownum 
            GROUP BY Year(pubDate)
            ORDER BY COUNT(*) DESC
        """
        max_year = network.mag.query_sql(query).toPandas()
        max_number = int(max_year.iloc[0].numReferences)

        print("The year {} had the maximum number of references produced: {}"
             .format(int(max_year.iloc[0]['year(pubDate)']), max_number))

        print("\nCreating slices")

        half_maxnum = int(max_number / 2)

        slice_records = []

        slice_idx = 0

        for i in range(1, num_references, half_maxnum):
            start_index = i
            end_index = i + max_number

            if end_index > num_references:
                end_index = num_references

            records = {
                'slice_index': slice_idx,
                'start_index': start_index,
                'end_index': end_index
            }

            slice_records.append(records)
            slice_idx += 1

            if end_index == num_references:
                break

        slices_df = pd.DataFrame.from_records(slice_records)

        all_indexes = list(slices_df.start_index.values) + list(slices_df.end_index.values)
        all_indexes_string = "(" + ",".join([str(x) for x in all_indexes]) + ")"

        query = """
            SELECT * FROM PaperReferencesRownum 
            WHERE rownum IN {}
        """.format(all_indexes_string)

        border_references = network.mag.query_sql(query)
        border_references_df = border_references.toPandas()

        slice_df = pd.merge(slices_df, border_references_df, how='left', left_on="start_index", right_on="rownum")
        slice_df = pd.merge(slice_df, border_references_df, how='left', left_on="end_index", right_on="rownum",
                            suffixes=('_lower', '_upper'))

        slice_df.to_csv(csv_filepath, index=False)
        print("{} slices identified. Saved to {}".format(len(slice_df), csv_filepath))
    
    slice_df = pd.read_csv(csv_filepath)
        
    # loop over rows and create networks
    for record in slice_df.to_dict('records'):

        print("Extracting {} slice index {} / {}".format(fos_name, record['slice_index'], len(slice_df)))

        network_name = "SimpleWeight{}2020Slice{}".format(fos_name, record['slice_index'])
        network.save_author_network(network_name, 
                                    mindate='1800-01-01', 
                                    maxdate='2020-12-31',
                                    min_rownum=record['start_index'],
                                    max_rownum=record['end_index'])

# %%
build_wacn_slices(162324750, 'Economics', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Economics2020.csv")
# Out:
# Paper references and citations available for Economics
# Extracting ordered references
# Extracting Economics slice index 0 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice0 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice0.txt
# Extracting Economics slice index 1 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice1 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice1.txt
# Extracting Economics slice index 2 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice2 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice2.txt
# Extracting Economics slice index 3 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice3 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice3.txt
# Extracting Economics slice index 4 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice4 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice4.txt
# Extracting Economics slice index 5 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice5 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice5.txt
# Extracting Economics slice index 6 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice6 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice6.txt
# Extracting Economics slice index 7 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice7 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice7.txt
# Extracting Economics slice index 8 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice8 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice8.txt
# Extracting Economics slice index 9 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice9 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice9.txt
# Extracting Economics slice index 10 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice10 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice10.txt
# Extracting Economics slice index 11 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice11 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice11.txt
# Extracting Economics slice index 12 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice12 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice12.txt
# Extracting Economics slice index 13 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice13 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice13.txt
# Extracting Economics slice index 14 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice14 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice14.txt
# Extracting Economics slice index 15 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice15 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice15.txt
# Extracting Economics slice index 16 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice16 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice16.txt
# Extracting Economics slice index 17 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice17 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice17.txt
# Extracting Economics slice index 18 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice18 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice18.txt
# Extracting Economics slice index 19 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice19 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice19.txt
# Extracting Economics slice index 20 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice20 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice20.txt
# Extracting Economics slice index 21 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice21 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice21.txt
# Extracting Economics slice index 22 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice22 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice22.txt
# Extracting Economics slice index 23 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice23 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice23.txt
# Extracting Economics slice index 24 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice24 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice24.txt
# Extracting Economics slice index 25 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice25 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice25.txt
# Extracting Economics slice index 26 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice26 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice26.txt
# Extracting Economics slice index 27 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice27 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice27.txt
# Extracting Economics slice index 28 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice28 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice28.txt
# Extracting Economics slice index 29 / 30
# Paper references and citations available for Economics
# Network SimpleWeightEconomics2020Slice29 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020Slice29.txt

# %%
build_wacn_slices(15744967, 'Psychology', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Psychology2020.csv")
# Out:
# Paper references and citations available for Psychology
# Extracting ordered references
# The year 2020 had the maximum number of references produced: 4614522
#
# Creating slices
# 28 slices identified. Saved to /home/laal/MAG/CentralityFairness/SLICES/Psychology2020.csv
# Extracting Psychology slice index 0 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice0 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice0.txt
# Extracting Psychology slice index 1 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice1 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice1.txt
# Extracting Psychology slice index 2 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice2 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice2.txt
# Extracting Psychology slice index 3 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice3 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice3.txt
# Extracting Psychology slice index 4 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice4 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice4.txt
# Extracting Psychology slice index 5 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice5 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice5.txt
# Extracting Psychology slice index 6 / 28
# Paper references and citations available for Psychology
# Network SimpleWeightPsychology2020Slice6 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020Slice6.txt
# Extracting Psychology slice index 7 / 28
# Paper references and citations available for Psychology

# %%
id_names = [(15744967, 'Psychology'), (33923547, 'Mathematics'), (162324750, 'Economics'), (185592680, 'Chemistry')]

# %%
build_wacn_slices(33923547, 'Mathematics', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Mathematics2020.csv")
# Out:
# Paper references and citations available for Mathematics
# Extracting ordered references
# Extracting Mathematics slice index 0 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice0.txt. Use overwrite to replace
# Extracting Mathematics slice index 1 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice1.txt. Use overwrite to replace
# Extracting Mathematics slice index 2 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice2.txt. Use overwrite to replace
# Extracting Mathematics slice index 3 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice3.txt. Use overwrite to replace
# Extracting Mathematics slice index 4 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice4.txt. Use overwrite to replace
# Extracting Mathematics slice index 5 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice5.txt. Use overwrite to replace
# Extracting Mathematics slice index 6 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice6.txt. Use overwrite to replace
# Extracting Mathematics slice index 7 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice7.txt. Use overwrite to replace
# Extracting Mathematics slice index 8 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice8.txt. Use overwrite to replace
# Extracting Mathematics slice index 9 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice9.txt. Use overwrite to replace
# Extracting Mathematics slice index 10 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice10.txt. Use overwrite to replace
# Extracting Mathematics slice index 11 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice11.txt. Use overwrite to replace
# Extracting Mathematics slice index 12 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice12.txt. Use overwrite to replace
# Extracting Mathematics slice index 13 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice13.txt. Use overwrite to replace
# Extracting Mathematics slice index 14 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice14.txt. Use overwrite to replace
# Extracting Mathematics slice index 15 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice15.txt. Use overwrite to replace
# Extracting Mathematics slice index 16 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice16.txt. Use overwrite to replace
# Extracting Mathematics slice index 17 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice17.txt. Use overwrite to replace
# Extracting Mathematics slice index 18 / 33
# Paper references and citations available for Mathematics
# Network SimpleWeightMathematics2020Slice18 saved to /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice18.txt
# Extracting Mathematics slice index 19 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice19.txt. Use overwrite to replace
# Extracting Mathematics slice index 20 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice20.txt. Use overwrite to replace
# Extracting Mathematics slice index 21 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice21.txt. Use overwrite to replace
# Extracting Mathematics slice index 22 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice22.txt. Use overwrite to replace
# Extracting Mathematics slice index 23 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice23.txt. Use overwrite to replace
# Extracting Mathematics slice index 24 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice24.txt. Use overwrite to replace
# Extracting Mathematics slice index 25 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice25.txt. Use overwrite to replace
# Extracting Mathematics slice index 26 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice26.txt. Use overwrite to replace
# Extracting Mathematics slice index 27 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice27.txt. Use overwrite to replace
# Extracting Mathematics slice index 28 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice28.txt. Use overwrite to replace
# Extracting Mathematics slice index 29 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice29.txt. Use overwrite to replace
# Extracting Mathematics slice index 30 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice30.txt. Use overwrite to replace
# Extracting Mathematics slice index 31 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice31.txt. Use overwrite to replace
# Extracting Mathematics slice index 32 / 33
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightMathematics2020Slice32.txt. Use overwrite to replace

# %%
build_wacn_slices(185592680, 'Chemistry', root_data_folder="/home/laal/MAG/DATA", 
                  csv_filepath="/home/laal/MAG/CentralityFairness/SLICES/Chemistry2020.csv")
# Out:
# Paper references and citations available for Chemistry
# Extracting ordered references
# Extracting Chemistry slice index 0 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice0.txt. Use overwrite to replace
# Extracting Chemistry slice index 1 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice1.txt. Use overwrite to replace
# Extracting Chemistry slice index 2 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice2.txt. Use overwrite to replace
# Extracting Chemistry slice index 3 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice3.txt. Use overwrite to replace
# Extracting Chemistry slice index 4 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice4.txt. Use overwrite to replace
# Extracting Chemistry slice index 5 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice5.txt. Use overwrite to replace
# Extracting Chemistry slice index 6 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice6.txt. Use overwrite to replace
# Extracting Chemistry slice index 7 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice7.txt. Use overwrite to replace
# Extracting Chemistry slice index 8 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice8.txt. Use overwrite to replace
# Extracting Chemistry slice index 9 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice9.txt. Use overwrite to replace
# Extracting Chemistry slice index 10 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice10.txt. Use overwrite to replace
# Extracting Chemistry slice index 11 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice11.txt. Use overwrite to replace
# Extracting Chemistry slice index 12 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice12.txt. Use overwrite to replace
# Extracting Chemistry slice index 13 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice13.txt. Use overwrite to replace
# Extracting Chemistry slice index 14 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice14.txt. Use overwrite to replace
# Extracting Chemistry slice index 15 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice15.txt. Use overwrite to replace
# Extracting Chemistry slice index 16 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice16.txt. Use overwrite to replace
# Extracting Chemistry slice index 17 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice17.txt. Use overwrite to replace
# Extracting Chemistry slice index 18 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice18.txt. Use overwrite to replace
# Extracting Chemistry slice index 19 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice19.txt. Use overwrite to replace
# Extracting Chemistry slice index 20 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice20.txt. Use overwrite to replace
# Extracting Chemistry slice index 21 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice21.txt. Use overwrite to replace
# Extracting Chemistry slice index 22 / 37
# Network exists at /home/laal/MAG/DATA/NETWORKS/SimpleWeightChemistry2020Slice22.txt. Use overwrite to replace
# Extracting Chemistry slice index 23 / 37
# Paper references and citations available for Chemistry

# %%
def author_metadata_field(mag):

    author_affiliations = mag.getDataframe('PaperAuthorAffiliations')
    authors = mag.getDataframe('WosToMag')
    paper_root_field = mag.getDataframe('PaperRootFieldMag')
    papers = mag.getDataframe('Papers')
    affiliation = mag.getDataframe('Affiliations')

    query = """
    SELECT paa.AuthorId, prf.FieldOfStudyId, 
    CASE WHEN wtm.Gender IN (0, 1) THEN wtm.Gender ELSE -1 END as Gender,
    MIN(a.Rank) as MinAffiliationRank,
    COUNT(DISTINCT(paa.PaperId)) as NumPapers,
    MIN(p.Date) as MinPubDate,
    MAX(p.Date) as MaxPubDate, 
    (COUNT(DISTINCT(paa.PaperId)) / (DATEDIFF( MAX(p.Date), MIN(p.Date) ) / 365)) as PubsPerYear
    FROM PaperAuthorAffiliations AS paa 
    INNER JOIN WosToMag AS wtm ON paa.AuthorId = wtm.MAG 
    INNER JOIN PaperRootFieldMag prf ON paa.PaperId = prf.PaperId
    INNER JOIN Papers p ON p.PaperId = paa.PaperId
    INNER JOIN Affiliations AS a ON paa.AffiliationId = a.AffiliationId
    GROUP BY paa.AuthorId, prf.FieldOfStudyId, CASE WHEN wtm.Gender IN (0, 1) THEN wtm.Gender ELSE -1 END 
    ORDER BY paa.AuthorId
    """
    author_metadata_df = mag.query_sql(query)
    return author_metadata_df

def author_metadata_global(mag):

    author_affiliations = mag.getDataframe('PaperAuthorAffiliations')
    authors = mag.getDataframe('WosToMag')
    paper_root_field = mag.getDataframe('PaperRootFieldMag')
    papers = mag.getDataframe('Papers')
    affiliation = mag.getDataframe('Affiliations')

    query = """
    SELECT paa.AuthorId,
    CASE WHEN wtm.Gender IN (0, 1) THEN wtm.Gender ELSE -1 END as Gender,
    MIN(a.Rank) as MinAffiliationRank,
    COUNT(DISTINCT(paa.PaperId)) as NumPapers,
    MIN(p.Date) as MinPubDate,
    MAX(p.Date) as MaxPubDate, 
    (COUNT(DISTINCT(paa.PaperId)) / (DATEDIFF( MAX(p.Date), MIN(p.Date) ) / 365)) as PubsPerYear
    FROM PaperAuthorAffiliations AS paa 
    INNER JOIN WosToMag AS wtm ON paa.AuthorId = wtm.MAG 
    INNER JOIN Papers p ON p.PaperId = paa.PaperId
    INNER JOIN Affiliations AS a ON paa.AffiliationId = a.AffiliationId
    GROUP BY paa.AuthorId, CASE WHEN wtm.Gender IN (0, 1) THEN wtm.Gender ELSE -1 END 
    ORDER BY paa.AuthorId
    """
    author_metadata_df = mag.query_sql(query)
    return author_metadata_df

# %%
author_metadata = author_metadata_field(mag)

# %%
author_metadata.write.option("sep", "\t").option("encoding", "UTF-8")\
.csv("/home/laal/MAG/DATA/AuthorMetadataField.csv")

# %%
author_metadata_cross = author_metadata_global(mag)

# %%
author_metadata_cross.write.option("sep", "\t").option("encoding", "UTF-8")\
.csv("/home/laal/MAG/DATA/AuthorMetadataGlobal.csv")

# %%
border_references = network.mag.query_sql(query)
border_references_df = border_references.toPandas()

# %%
border_references_df.head()
# Out:
#       PaperId  PaperReferenceId     pubDate   rownum
# 0  2249592763        1994000457        None        1
# 1  1993370695        2070557914  1988-01-23   574432
# 2  2073598084        2056566288  1994-02-01  1148863
# 3  2099822008        2137873244  1998-01-01  1723294
# 4  2089901068        2034903818  2000-08-01  2297725

# %%
slice_df = pd.merge(slices_df, border_references_df, how='left', left_on="start_index", right_on="rownum")
slice_df = pd.merge(slice_df, border_references_df, how='left', left_on="end_index", right_on="rownum",
                    suffixes=('_lower', '_upper'))
slice_df
# Out:
#     slice_index  start_index  end_index  PaperId_lower  \
# 0             0            1    1148863     2249592763
# 1             1       574432    1723294     1993370695
# 2             2      1148863    2297725     2073598084
# 3             3      1723294    2872156     2099822008
# 4             4      2297725    3446587     2089901068
# 5             5      2872156    4021018     2097503557
# 6             6      3446587    4595449     1603530799
# 7             7      4021018    5169880     1487271016
# 8             8      4595449    5744311     2150065779
# 9             9      5169880    6318742      204190154
# 10           10      5744311    6893173       72680553
# 11           11      6318742    7467604     2026785174
# 12           12      6893173    8042035     1535590298
# 13           13      7467604    8616466     2095648252
# 14           14      8042035    9190897     1820062941
# 15           15      8616466    9765328     2121672329
# 16           16      9190897   10339759     2186652452
# 17           17      9765328   10914190      143002236
# 18           18     10339759   11488621     2186762713
# 19           19     10914190   12063052     1987480565
# 20           20     11488621   12637483      307471830
# 21           21     12063052   13211914     2163260251
# 22           22     12637483   13786345     2077707094
# 23           23     13211914   14360776     2157355505
# 24           24     13786345   14935207     2953826709
# 25           25     14360776   15509638     2559410470
# 26           26     14935207   16084069     2736099742
# 27           27     15509638   16658500     2622463117
# 28           28     16084069   17232931     2805580967
# 29           29     16658500   17334946     3007718862
#
#     PaperReferenceId_lower pubDate_lower  rownum_lower  PaperId_upper  \
# 0               1994000457          None             1     2073598084
# 1               2070557914    1988-01-23        574432     2099822008
# 2               2056566288    1994-02-01       1148863     2089901068
# 3               2137873244    1998-01-01       1723294     2097503557
# 4               2034903818    2000-08-01       2297725     1603530799
# 5               2052618091    2002-05-01       2872156     1487271016
# 6               2010997253    2003-11-14       3446587     2150065779
# 7               1544472346    2005-01-01       4021018      204190154
# 8               1486206345    2006-01-01       4595449       72680553
# 9               2978664979    2007-01-01       5169880     2026785174
# 10              2093759895    2008-01-01       5744311     1535590298
# 11              2025195871    2008-09-12       6318742     2095648252
# 12              1490946364    2009-05-01       6893173     1820062941
# 13              2168794914    2010-01-01       7467604     2121672329
# 14              2038714558    2010-11-01       8042035     2186652452
# 15              2156109180    2011-05-01       8616466      143002236
# 16              2128778916    2012-01-01       9190897     2186762713
# 17              2117057028    2012-08-01       9765328     1987480565
# 18              2048427578    2013-01-01      10339759      307471830
# 19              1536604454    2013-09-01      10914190     2163260251
# 20              2142614759    2014-02-01      11488621     2077707094
# 21              2081169337    2014-09-04      12063052     2157355505
# 22              3020873074    2015-02-05      12637483     2953826709
# 23              2126647137    2015-10-01      13211914     2559410470
# 24              2138209548    2016-03-14      13786345     2736099742
# 25              2142551384    2016-11-30      14360776     2622463117
# 26              1985537936    2017-06-06      14935207     2805580967
# 27              2164094226    2018-03-01      15509638     3007718862
# 28              2042975625    2019-03-01      16084069     3108842795
# 29              2151021552    2020-02-22      16658500     2184085909
#
#     PaperReferenceId_upper pubDate_upper  rownum_upper
# 0               2056566288    1994-02-01       1148863
# 1               2137873244    1998-01-01       1723294
# 2               2034903818    2000-08-01       2297725
# 3               2052618091    2002-05-01       2872156
# 4               2010997253    2003-11-14       3446587
# 5               1544472346    2005-01-01       4021018
# 6               1486206345    2006-01-01       4595449
# 7               2978664979    2007-01-01       5169880
# 8               2093759895    2008-01-01       5744311
# 9               2025195871    2008-09-12       6318742
# 10              1490946364    2009-05-01       6893173
# 11              2168794914    2010-01-01       7467604
# 12              2038714558    2010-11-01       8042035
# 13              2156109180    2011-05-01       8616466
# 14              2128778916    2012-01-01       9190897
# 15              2117057028    2012-08-01       9765328
# 16              2048427578    2013-01-01      10339759
# 17              1536604454    2013-09-01      10914190
# 18              2142614759    2014-02-01      11488621
# 19              2081169337    2014-09-04      12063052
# 20              3020873074    2015-02-05      12637483
# 21              2126647137    2015-10-01      13211914
# 22              2138209548    2016-03-14      13786345
# 23              2142551384    2016-11-30      14360776
# 24              1985537936    2017-06-06      14935207
# 25              2164094226    2018-03-01      15509638
# 26              2042975625    2019-03-01      16084069
# 27              2151021552    2020-02-22      16658500
# 28                64196434    2020-12-02      17232931
# 29              2153001498    2021-07-01      17334946

# %%
spark.stop()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 125

# %%
prefs_with_rownum.count()
# Out:
# 10000

# %%
print("The year {} had maximum number of references produced: {}"
     .format(int(max_year.iloc[0]['year(pubDate)']), int(max_year.iloc[0].numReferences)))
# Out:
# The year 2014 had maximum number of references produced: 1148862

# %%
df =

# %%
max_year.head(25)
# Out:
#     year(pubDate)  numReferences
# 0          2014.0        1148862
# 1          2015.0        1098134
# 2          2013.0        1082510
# 3          2012.0        1004167
# 4          2016.0        1003796
# 5          2011.0         941282
# 6          2017.0         914149
# 7          2010.0         865657
# 8          2009.0         806580
# 9          2020.0         745518
# 10         2008.0         730197
# 11         2007.0         652476
# 12         2019.0         598270
# 13         2006.0         589728
# 14         2018.0         579223
# 15         2005.0         537847
# 16         2004.0         482183
# 17         2003.0         435070
# 18         2002.0         363445
# 19         2001.0         306202
# 20         2000.0         264720
# 21         1999.0         233579
# 22         1998.0         191994
# 23         1997.0         161617
# 24         1996.0         152934

# %%
network.mag.streams
# Out:
# {'Affiliations': ('Affiliations.txt',
#   ['AffiliationId:long',
#    'Rank:uint',
#    'NormalizedName:string',
#    'DisplayName:string',
#    'GridId:string',
#    'OfficialPage:string',
#    'WikiPage:string',
#    'PaperCount:long',
#    'PaperFamilyCount:long',
#    'CitationCount:long',
#    'Iso3166Code:string',
#    'Latitude:float?',
#    'Longitude:float?',
#    'CreatedDate:DateTime']),
#  'Authors': ('Authors.txt',
#   ['AuthorId:long',
#    'Rank:uint',
#    'NormalizedName:string',
#    'DisplayName:string',
#    'LastKnownAffiliationId:long?',
#    'PaperCount:long',
#    'PaperFamilyCount:long',
#    'CitationCount:long',
#    'CreatedDate:DateTime']),
#  'FieldOfStudyChildren': ('FieldOfStudyChildren.txt',
#   ['FieldOfStudyId:long', 'ChildFieldOfStudyId:long']),
#  'FieldsOfStudy': ('FieldsOfStudy.txt',
#   ['FieldOfStudyId:long',
#    'Rank:uint',
#    'NormalizedName:string',
#    'DisplayName:string',
#    'MainType:string',
#    'Level:int',
#    'PaperCount:long',
#    'PaperFamilyCount:long',
#    'CitationCount:long',
#    'CreatedDate:DateTime']),
#  'PaperAuthorAffiliations': ('PaperAuthorAffiliations.txt',
#   ['PaperId:long',
#    'AuthorId:long',
#    'AffiliationId:long?',
#    'AuthorSequenceNumber:uint',
#    'OriginalAuthor:string',
#    'OriginalAffiliation:string']),
#  'PaperFieldsOfStudy': ('PaperFieldsOfStudy.txt',
#   ['PaperId:long', 'FieldOfStudyId:long', 'Score:float']),
#  'PaperReferences': ('PaperReferences.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'Papers': ('Papers.txt',
#   ['PaperId:long',
#    'Rank:uint',
#    'Doi:string',
#    'DocType:string',
#    'PaperTitle:string',
#    'OriginalTitle:string',
#    'BookTitle:string',
#    'Year:int?',
#    'Date:DateTime?',
#    'OnlineDate:DateTime?',
#    'Publisher:string',
#    'JournalId:long?',
#    'ConferenceSeriesId:long?',
#    'ConferenceInstanceId:long?',
#    'Volume:string',
#    'Issue:string',
#    'FirstPage:string',
#    'LastPage:string',
#    'ReferenceCount:long',
#    'CitationCount:long',
#    'EstimatedCitation:long',
#    'OriginalVenue:string',
#    'FamilyId:long?',
#    'FamilyRank:uint?',
#    'CreatedDate:DateTime']),
#  'RelatedFieldOfStudy': ('RelatedFieldOfStudy.txt',
#   ['FieldOfStudyId1:long',
#    'Type1:string',
#    'FieldOfStudyId2:long',
#    'Type2:string',
#    'Rank:float']),
#  'WosToMag': ('WosToMag.txt', ['WOS:long', 'MAG:long', 'Gender:int']),
#  'FieldOfStudyRoot': ('FieldOfStudyRoot.txt',
#   ['ChildId:long', 'AncestorId:long']),
#  'AuthorCountry': ('AuthorCountry.txt',
#   ['AuthorId:long',
#    'CountryCode:string',
#    'NumAffiliations:int',
#    'CountryRank:int']),
#  'PaperRootField': ('PaperRootField.csv',
#   ['PaperId:long',
#    'AncestorId:long',
#    'NumSubfieldsInField:int',
#    'fieldRank:int']),
#  'PaperRootFieldMag': ('PaperRootFieldMag.txt',
#   ['PaperId:long', 'FieldOfStudyId:long']),
#  'AuthorRootField': ('AuthorRootField.csv',
#   ['AuthorId:long',
#    'AncestorId:long',
#    'NumPapersInField:int',
#    'fieldRank:int']),
#  'AuthorsPerPaper': ('AuthorsPerPaper.txt',
#   ['PaperId:long', 'NumAuthors:int', 'Weight:float', 'NumMagGendered:int']),
#  'Citations': ('Citations.tsv',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsFromUnknownGender': ('CitationsFromUnknownGender.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsToUnknownGender': ('CitationsToUnknownGender.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'PaperAuthorAffiliationsGendered': ('PaperAuthorAffiliationsGendered.txt',
#   ['PaperId:long', 'AuthorId:long', 'Gender:int']),
#  'PaperAuthorAffiliationsGenderedFull': ('PaperAuthorAffiliationsGenderedFull.txt',
#   ['PaperId:long', 'AuthorId:long', 'Gender:int']),
#  'NumAuthorsPerPaper': ('NumAuthorsPerPaper.txt',
#   ['PaperId:long', 'NumAuthors:int', 'PublishDate:DateTime']),
#  'PaperReferencesMedicine': ('PaperReferencesMedicine.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'PaperReferencesBiology': ('PaperReferencesBiology.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'PaperReferencesChemistry': ('PaperReferencesChemistry.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'PaperReferencesPsychology': ('PaperReferencesPsychology.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'PaperReferencesMathematics': ('PaperReferencesMathematics.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'PaperReferencesEconomics': ('PaperReferencesEconomics.txt',
#   ['PaperId:long', 'PaperReferenceId:long']),
#  'CitationsBiology': ('CitationsBiology.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsChemistry': ('CitationsChemistry.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsMathematics': ('CitationsMathematics.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsMedicine': ('CitationsMedicine.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsPsychology': ('CitationsPsychology.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int']),
#  'CitationsEconomics': ('CitationsEconomics.txt',
#   ['CitingAuthorId:long',
#    'CitingPaperId:long',
#    'CitingAuthorGender:int',
#    'CitedAuthorId:long',
#    'CitedPaperId:long',
#    'CitedAuthorGender:int'])}

# %%
econ_refs = mag.getDataframe('FieldsOfStudy')

query = """
        SELECT 
        FieldOfStudyId, Rank, NormalizedName,
        row_number() over (order by Rank ASC) rownum
        FROM FieldsOfStudy
        LIMIT 1000
    """
    
# execute query and convert to pandas dataframe
test = mag.query_sql(query)

# %%
test.toPandas()
# Out:
#      FieldOfStudyId  Rank          NormalizedName  rownum
# 0          71924100  4083                medicine       1
# 1         192562407  4130       materials science       2
# 2          41008148  4284        computer science       3
# 3         185592680  4331               chemistry       4
# 4          86803240  4390                 biology       5
# ..              ...   ...                     ...     ...
# 995      2779341262  9084                immunity     996
# 996        60798267  9084                division     997
# 997        58489278  9086                data set     998
# 998        93391505  9087  reaction rate constant     999
# 999       182748727  9087         reynolds number    1000
#
# [1000 rows x 4 columns]
