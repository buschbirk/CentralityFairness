# %%
import pandas as pd
import numpy as np
from MAG_network import CitationNetwork

from matplotlib import pyplot as plt

import sys

sys.path.insert(0,"/home/laal/MAG/CentralityFairness/Evaluations")

from Evaluations.Evaluator import Evaluator


plt.style.use('ggplot')

# %%
econ_centrality = pd.read_csv("/home/laal/MAG/DATA/NETWORKS/SimpleWeightEconomics2020CentralityGendered.csv", 
                              sep="\t").query("Gender != -1")
psych_centrality = pd.read_csv("/home/laal/MAG/DATA/NETWORKS/SimpleWeightPsychology2020CentralityGendered.csv", 
                              sep="\t").query("Gender != -1")

# %%
METRICS = ['rND']
CENTRALITIES = ['PageRank', 'PageRank05', 'InDegreeStrength', 'Rank']
cutpoint = 10
    
def evaluate(centrality, data):
    eval = Evaluator(centrality=centrality, data=data)
    return eval.run_evaluations(METRICS)

# %%
score_records_econ = []
score_records_psych = []


for samplen in range(20000, econ_centrality.shape[0], 20000):
    scores_econ = evaluate('PageRank', econ_centrality.sample(samplen, random_state=samplen))
    score_records_econ.append(scores_econ)
    
    scores_psych = evaluate('PageRank', psych_centrality.sample(samplen, random_state=samplen))
    score_records_psych.append(scores_psych)
    
econ_scores = pd.DataFrame.from_records(score_records_econ)
psych_scores = pd.DataFrame.from_records(score_records_psych)
# Out:
# gender counts normalized:
# 1    0.7274
# 0    0.2726
# Name: Gender, dtype: float64
# gender counts:
# 1    14548
# 0     5452
# Name: Gender, dtype: int64
# sorted data.head():
#               item      rank  PageRank05  InDegreeStrength  InDegree  \
# 760842  2397423007  0.001323    0.000483         33472.990   24635.0
# 335001  2099607353  0.000858    0.000280         12258.514   12545.0
# 422325  1970476475  0.000748    0.000344         25434.830   26085.0
# 133206   621481202  0.000544    0.000231          8662.692    8800.0
# 205359  2187985802  0.000509    0.000226          7085.694    8056.0
#
#         OutDegreeStrength  OutDegree  Gender   Rank  protected
# 760842         4898.27440     1682.0       1  11754          0
# 335001          947.90753      656.0       1  12087          0
# 422325         5402.52100     3400.0       1  11959          0
# 133206          955.72620      585.0       1  12753          0
# 205359            0.00000        0.0       1  13121          0
# gender counts normalized:
# 0    0.50295
# 1    0.49705
# Name: Gender, dtype: float64
# gender counts:
# 0    10059
# 1     9941
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 3121196  2132298399  0.000318    0.000163        15950.2610   48566.0
# 2796566  2148669659  0.000281    0.000119        18071.2930   28886.0
# 2797652  2158373995  0.000241    0.000085        11133.5740   12891.0
# 2789714  2096636255  0.000163    0.000067         5738.4956   11856.0
# 740664   1822537265  0.000128    0.000058        10800.6820   59087.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 3121196          256.83014      824.0       1  10999          0
# 2796566         2995.52560     4887.0       1  11824          0
# 2797652         1108.33340     1385.0       0  13348          1
# 2789714          431.44287      826.0       1  12607          0
# 740664          2984.98950    17149.0       1  11972          0
# gender counts normalized:
# 1    0.732475
# 0    0.267525
# Name: Gender, dtype: float64
# gender counts:
# 1    29299
# 0    10701
# Name: Gender, dtype: int64
# sorted data.head():
#               item      rank  PageRank05  InDegreeStrength  InDegree  \
# 229876  2328689955  0.001521    0.000516         18587.943   18334.0
# 93367   2159466601  0.001286    0.000436         19330.660   24878.0
# 556081  2090569453  0.000979    0.000293         14177.552   12314.0
# 186932  2495582284  0.000718    0.000233          5951.067    7661.0
# 333342  1880039828  0.000645    0.000280         14517.418   19130.0
#
#         OutDegreeStrength  OutDegree  Gender   Rank  protected
# 229876          197.28462      183.0       1  11845          0
# 93367          1513.20840     1139.0       1  11759          0
# 556081         2663.99170     1409.0       1  12348          0
# 186932           38.00000       32.0       1  13102          0
# 333342         1621.91940     1217.0       1  12058          0
# gender counts normalized:
# 0    0.500825
# 1    0.499175
# Name: Gender, dtype: float64
# gender counts:
# 0    20033
# 1    19967
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 3369847  2157867866  0.000535    0.000249        18539.3610   43109.0
# 2539323  1978784284  0.000177    0.000095        25778.6020   56119.0
# 578423   1960361517  0.000156    0.000079        11054.8710   17338.0
# 3446638  2116034858  0.000155    0.000056         8456.1490   17846.0
# 1735172  2162998089  0.000146    0.000061         7553.1763   28340.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 3369847            31.5000       83.0       1  12516          0
# 2539323          6854.0410    19253.0       1  12293          0
# 578423            823.5000      967.0       1  12953          0
# 3446638          1518.9683     2146.0       1  13201          0
# 1735172           985.1508     1933.0       1  12840          0
# gender counts normalized:
# 1    0.732483
# 0    0.267517
# Name: Gender, dtype: float64
# gender counts:
# 1    43949
# 0    16051
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 229876   2328689955  0.001521    0.000516         18587.943   18334.0
# 1045127  2163419371  0.001182    0.000449         14796.059   22749.0
# 2397     2042602993  0.001174    0.000532         15076.861   15099.0
# 686434    699751090  0.001042    0.000421         12110.575   14133.0
# 78333    2603972192  0.000972    0.000475         25397.588   21605.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 229876          197.284620      183.0       1  11845          0
# 1045127         623.224200      426.0       1  11921          0
# 2397             77.500000       83.0       1  12328          0
# 686434          121.333336      111.0       1  12034          0
# 78333           503.590270      413.0       1  12379          0
# gender counts normalized:
# 0    0.501767
# 1    0.498233
# Name: Gender, dtype: float64
# gender counts:
# 0    30106
# 1    29894
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 1250821  2286094323  0.000225    0.000082       10653.77600   10783.0
# 2866381  1970913371  0.000181    0.000070       16446.75400   37178.0
# 737545    186718860  0.000150    0.000083        9799.66700   21011.0
# 1646971  2108392708  0.000149    0.000085       14380.08200   44853.0
# 1023427  2574861158  0.000147    0.000018         727.11664    1189.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 1250821          2797.7102     2002.0       1  13097          0
# 2866381          3861.8855     7793.0       1  12748          0
# 737545           1491.2008     3442.0       1  11751          0
# 1646971          1175.2186     3686.0       1  12315          0
# 1023427             1.0000        1.0       1  13683          0
# gender counts normalized:
# 1    0.7328
# 0    0.2672
# Name: Gender, dtype: float64
# gender counts:
# 1    58624
# 0    21376
# Name: Gender, dtype: int64
# sorted data.head():
#               item      rank  PageRank05  InDegreeStrength  InDegree  \
# 891971  2293679170  0.002441    0.000881         43244.740   35847.0
# 291988  2126675098  0.002057    0.000927         35671.740   34202.0
# 578961  2119427290  0.001104    0.000490         14155.820   22355.0
# 204379  2153576001  0.001091    0.000488         26835.293   29445.0
# 777340  2106981306  0.001074    0.000430         27886.860   24679.0
#
#         OutDegreeStrength  OutDegree  Gender   Rank  protected
# 891971         1549.18370     1183.0       1  11693          0
# 291988          560.33405      760.0       1  11366          0
# 578961          239.00000      196.0       1  11892          0
# 204379          671.98610      557.0       1  11790          0
# 777340         1920.03900     1359.0       1  12009          0
# gender counts normalized:
# 0    0.50185
# 1    0.49815
# Name: Gender, dtype: float64
# gender counts:
# 0    40148
# 1    39852
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 3369847  2157867866  0.000535    0.000249         18539.361   43109.0
# 2058547  2131203610  0.000263    0.000126         28869.295   47503.0
# 3689683  2096686297  0.000208    0.000118         24136.047   39747.0
# 1653137  2157138196  0.000204    0.000106         19135.293  106662.0
# 985641   1864732433  0.000189    0.000099         14371.452   29352.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 3369847            31.5000       83.0       1  12516          0
# 2058547          5146.7163     7204.0       1  12406          0
# 3689683          7000.1780     8012.0       1  12181          0
# 1653137          2294.8027    13603.0       1  11011          0
# 985641           1786.2068     2746.0       1  12496          0
# gender counts normalized:
# 1    0.73154
# 0    0.26846
# Name: Gender, dtype: float64
# gender counts:
# 1    73154
# 0    26846
# Name: Gender, dtype: int64
# sorted data.head():
#               item      rank  PageRank05  InDegreeStrength  InDegree  \
# 291988  2126675098  0.002057    0.000927         35671.740   34202.0
# 996923  1958827600  0.001915    0.000782         27164.512   24704.0
# 864031  1965572909  0.001804    0.000594         27679.473   15704.0
# 229876  2328689955  0.001521    0.000516         18587.943   18334.0
# 34227   2612173084  0.001104    0.000344         13827.267    8148.0
#
#         OutDegreeStrength  OutDegree  Gender   Rank  protected
# 291988          560.33405      760.0       1  11366          0
# 996923         1217.82410      696.0       1  11898          0
# 864031         3374.02080     1222.0       1  11708          0
# 229876          197.28462      183.0       1  11845          0
# 34227          3489.85550     1014.0       1  12635          0
# gender counts normalized:
# 1    0.50042
# 0    0.49958
# Name: Gender, dtype: float64
# gender counts:
# 1    50042
# 0    49958
# Name: Gender, dtype: int64
# sorted data.head():
#                item      rank  PageRank05  InDegreeStrength  InDegree  \
# 1813673  2132289742  0.000860    0.000515         77976.390  155403.0
# 1975234  2116067072  0.000502    0.000239         35619.027  107652.0
# 164460    182094527  0.000289    0.000141         23576.057   44515.0
# 1887623  2022872097  0.000285    0.000183         20053.947   27887.0
# 2058547  2131203610  0.000263    0.000126         28869.295   47503.0
#
#          OutDegreeStrength  OutDegree  Gender   Rank  protected
# 1813673          217.08562     1378.0       0  11958          1
# 1975234         3024.47100     9136.0       1  11410          0
# 164460          1392.47010     4293.0       1  12472          0
# 1887623            8.00000       12.0       1  11861          0
# 2058547         5146.71630     7204.0       1  12406          0

# %%
econ_global = evaluate('PageRank', econ_centrality)
psych_global = evaluate('PageRank', psych_centrality)

econ_scores.index = list(range(20000, econ_centrality.shape[0], 20000))
psych_scores.index = list(range(20000, econ_centrality.shape[0], 20000))

# %%
plt.figure(figsize=(12, 8))
econ_scores['rND'].plot(style='-o', figsize=(12,8), label="Economics")
psych_scores['rND'].plot(style='-o', figsize=(12,8), label="Psychology")

plt.axhline(y=econ_global['rND'], label="Economics global", linestyle='--', alpha=0.4, color="orangered")
plt.axhline(y=psych_global['rND'], label="Psychology global", linestyle='--', alpha=1, color="lightblue")


plt.ylim(0.08, 0.14)
plt.title("rND with increasing sample sizes (PageRank). Cutpoint = {}".format(cutpoint))
plt.ylabel('rND')
plt.xlabel("Sample size")
plt.legend()
plt.savefig("rnd_sample_sizes_cutpoint_{}.png".format(cutpoint))
plt.show()
